# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime       #时间特征相关计算
import gc             #del某个变量后 通过gc.collect()收集垃圾释放系统内存

# %%
# %%time
df_hist_trans = pd.read_csv('historical_transactions.csv',parse_dates=['purchase_date'])
df_new_trans = pd.read_csv('new_merchant_transactions.csv',parse_dates=['purchase_date'])
# Out:
# CPU times: user 1min 6s, sys: 3.94 s, total: 1min 10s
# Wall time: 1min 10s

# %%
df_train = pd.read_csv('train.csv',parse_dates=['first_active_month'])
df_test = pd.read_csv('test.csv',parse_dates=['first_active_month'])

# %%
df_train.isna().sum()
# Out:
# first_active_month    0
# card_id               0
# feature_1             0
# feature_2             0
# feature_3             0
# target                0
# dtype: int64

# %%
df_train.nunique()
# Out:
# first_active_month        75
# card_id               201917
# feature_1                  5
# feature_2                  3
# feature_3                  2
# target                197110
# dtype: int64

# %% [markdown]
# ---

# %%
fig = plt.figure(figsize=(8,4))
ax = fig.add_axes((0,0,1,1))
sns.distplot(df_train['first_active_month'], bins =170,kde=False,color='green')

# %%
#target 顺序已经被打乱
fig = plt.figure(figsize=(10,12))
ax = fig.add_axes([0,0,1,1])
plt.scatter(x=range(len(df_train)),y=df_train.target,s=0.03,alpha=0.2)

# %% [markdown]
# ---

# %%
df_merge_hist = pd.merge(df_hist_trans,df_train,how='left',on='card_id')

# %%
df_merge_hist = df_merge_hist[-df_merge_hist['target'].isna()]

# %%
df_merge_hist.head()
# Out:
#     authorized_flag          card_id  city_id category_1  installments  \
# 400               N  C_ID_5037ff576e      322          N             1
# 401               Y  C_ID_5037ff576e      138          N             1
# 402               Y  C_ID_5037ff576e      138          N             1
# 403               Y  C_ID_5037ff576e      226          N             1
# 404               Y  C_ID_5037ff576e      330          N             1
#
#     category_3  merchant_category_id      merchant_id  month_lag  \
# 400          B                   278  M_ID_b61c7d1be0         -3
# 401          B                   307  M_ID_fe69229f24         -4
# 402          B                   705  M_ID_efc106141c         -9
# 403          B                   307  M_ID_708022307c         -4
# 404          B                   705  M_ID_393b4b8cec         -9
#
#      purchase_amount       purchase_date  category_2  state_id  subsector_id  \
# 400        -0.595260 2017-09-07 20:57:19         3.0        11            37
# 401         1.189469 2017-08-14 15:46:08         1.0        15            19
# 402        -0.640069 2017-03-05 14:57:51         1.0        15            33
# 403        -0.652256 2017-08-15 10:45:28         1.0        16            19
# 404        -0.674210 2017-03-26 20:00:31         3.0        17            33
#
#     first_active_month  feature_1  feature_2  feature_3    target
# 400         2017-01-01        5.0        1.0        1.0 -2.352713
# 401         2017-01-01        5.0        1.0        1.0 -2.352713
# 402         2017-01-01        5.0        1.0        1.0 -2.352713
# 403         2017-01-01        5.0        1.0        1.0 -2.352713
# 404         2017-01-01        5.0        1.0        1.0 -2.352713

# %%
df_merge_hist.isna().sum()/df_merge_hist.shape[0]
# Out:
# authorized_flag         0.000000
# card_id                 0.000000
# city_id                 0.000000
# category_1              0.000000
# installments            0.000000
# category_3              0.006129
# merchant_category_id    0.000000
# merchant_id             0.004771
# month_lag               0.000000
# purchase_amount         0.000000
# purchase_date           0.000000
# category_2              0.090815
# state_id                0.000000
# subsector_id            0.000000
# first_active_month      0.000000
# feature_1               0.000000
# feature_2               0.000000
# feature_3               0.000000
# target                  0.000000
# dtype: float64

# %%
df_hist_trans.isna().sum()/df_hist_trans.shape[0]
# Out:
# authorized_flag         0.000000
# card_id                 0.000000
# city_id                 0.000000
# category_1              0.000000
# installments            0.000000
# category_3              0.006120
# merchant_category_id    0.000000
# merchant_id             0.004757
# month_lag               0.000000
# purchase_amount         0.000000
# purchase_date           0.000000
# category_2              0.091125
# state_id                0.000000
# subsector_id            0.000000
# dtype: float64

# %%
df_merge_hist['month_diff1'] = ((datetime.datetime.today() - df_merge_hist['purchase_date']).dt.days)//30
df_merge_hist['month_diff1'] += df_merge_hist['month_lag']

# %%
df_merge_hist['outliers'] = df_merge_hist['target']<=-30

# %%
df_merge_hist = df_merge_hist[df_merge_hist['outliers']==False]

# %%
df_merge_hist.head(30)
# Out:
#     authorized_flag          card_id  city_id category_1  installments  \
# 400               N  C_ID_5037ff576e      322          N             1
# 401               Y  C_ID_5037ff576e      138          N             1
# 402               Y  C_ID_5037ff576e      138          N             1
# 403               Y  C_ID_5037ff576e      226          N             1
# 404               Y  C_ID_5037ff576e      330          N             1
# 405               Y  C_ID_5037ff576e      138          N             1
# 406               Y  C_ID_5037ff576e      278          N             1
# 407               N  C_ID_5037ff576e      221          N             1
# 408               Y  C_ID_5037ff576e       19          N             1
# 409               Y  C_ID_5037ff576e      331          N             1
# 410               N  C_ID_5037ff576e      211          N             1
# 411               Y  C_ID_5037ff576e      209          N             1
# 412               Y  C_ID_5037ff576e      193          N             1
# 413               Y  C_ID_5037ff576e      331          N             1
# 414               N  C_ID_5037ff576e       11          N             1
# 415               Y  C_ID_5037ff576e      331          N             1
# 416               Y  C_ID_5037ff576e      161          N             1
# 417               Y  C_ID_5037ff576e      330          N             1
# 418               Y  C_ID_5037ff576e       -1          N             1
# 419               Y  C_ID_5037ff576e      322          N             1
# 420               Y  C_ID_5037ff576e      105          N             1
# 421               Y  C_ID_5037ff576e       19          N             1
# 422               Y  C_ID_5037ff576e      331          N             1
# 423               Y  C_ID_5037ff576e      138          N             1
# 424               Y  C_ID_5037ff576e      331          N             1
# 425               Y  C_ID_5037ff576e       -1          N             1
# 426               Y  C_ID_5037ff576e      329          N             1
# 427               Y  C_ID_5037ff576e      138          N             1
# 428               Y  C_ID_5037ff576e       19          N             1
# 429               Y  C_ID_5037ff576e       42          N             1
#
#     category_3  merchant_category_id      merchant_id  month_lag  \
# 400          B                   278  M_ID_b61c7d1be0         -3
# 401          B                   307  M_ID_fe69229f24         -4
# 402          B                   705  M_ID_efc106141c         -9
# 403          B                   307  M_ID_708022307c         -4
# 404          B                   705  M_ID_393b4b8cec         -9
# 405          B                   307  M_ID_fe69229f24         -9
# 406          B                   705  M_ID_d70b0fd11b         -6
# 407          B                   307  M_ID_16cf5cd707         -1
# 408          B                   278  M_ID_6a5ddaaba7         -8
# 409          B                   332  M_ID_46ab73a225         -2
# 410          B                   307  M_ID_d23623b922         -3
# 411          B                   705  M_ID_04575c5e32        -11
# 412          B                   278  M_ID_f187d5d98c        -10
# 413          B                   278  M_ID_d86b8cc0eb         -4
# 414          B                   333  M_ID_a21fe5f7ad         -5
# 415          B                   705  M_ID_1529b56c2f        -10
# 416          B                   506  M_ID_97aebf8941        -11
# 417          B                   278  M_ID_80235aa624        -11
# 418          B                   307  M_ID_d8281a0ff9        -11
# 419          B                   278  M_ID_b61c7d1be0         -3
# 420          B                   307  M_ID_7054e1665d        -10
# 421          B                   278  M_ID_6a5ddaaba7        -10
# 422          B                   108  M_ID_c0e83eea18         -9
# 423          B                   705  M_ID_efc106141c         -9
# 424          B                   278  M_ID_06a964fa48        -10
# 425          B                   307  M_ID_949996e6b5          0
# 426          B                   278  M_ID_c12b6ae2fa        -10
# 427          B                   307  M_ID_fe69229f24         -9
# 428          B                   307  M_ID_f9184e1062         -4
# 429          B                   705  M_ID_645739547c         -6
#
#      purchase_amount    ...    category_2  state_id  subsector_id  \
# 400        -0.595260    ...           3.0        11            37
# 401         1.189469    ...           1.0        15            19
# 402        -0.640069    ...           1.0        15            33
# 403        -0.652256    ...           1.0        16            19
# 404        -0.674210    ...           3.0        17            33
# 405        -0.671775    ...           1.0        15            19
# 406        -0.627477    ...           5.0         5            33
# 407        -0.658296    ...           2.0        24            19
# 408        -0.696569    ...           1.0         9            37
# 409        -0.521510    ...           1.0        16             2
# 410         0.075749    ...           3.0        19            19
# 411        -0.716434    ...           1.0         9            33
# 412        -0.700326    ...           1.0        15            37
# 413        -0.671024    ...           1.0        16            37
# 414         0.495199    ...           2.0        23            10
# 415        -0.698027    ...           1.0        16            33
# 416        -0.443372    ...           3.0         3            30
# 417        -0.677786    ...           3.0        17            37
# 418        -0.303581    ...           NaN        -1            19
# 419        -0.595260    ...           3.0        11            37
# 420        -0.587341    ...           1.0         9            19
# 421        -0.678086    ...           1.0         9            37
# 422        -0.631204    ...           1.0        16            34
# 423        -0.686772    ...           1.0        15            33
# 424        -0.688455    ...           3.0         3            37
# 425        -0.671775    ...           NaN        -1            19
# 426        -0.701828    ...           1.0         9            37
# 427        -0.671775    ...           1.0        15            19
# 428        -0.340471    ...           1.0         9            19
# 429        -0.612871    ...           3.0        19            33
#
#      first_active_month feature_1  feature_2  feature_3    target  \
# 400          2017-01-01       5.0        1.0        1.0 -2.352713
# 401          2017-01-01       5.0        1.0        1.0 -2.352713
# 402          2017-01-01       5.0        1.0        1.0 -2.352713
# 403          2017-01-01       5.0        1.0        1.0 -2.352713
# 404          2017-01-01       5.0        1.0        1.0 -2.352713
# 405          2017-01-01       5.0        1.0        1.0 -2.352713
# 406          2017-01-01       5.0        1.0        1.0 -2.352713
# 407          2017-01-01       5.0        1.0        1.0 -2.352713
# 408          2017-01-01       5.0        1.0        1.0 -2.352713
# 409          2017-01-01       5.0        1.0        1.0 -2.352713
# 410          2017-01-01       5.0        1.0        1.0 -2.352713
# 411          2017-01-01       5.0        1.0        1.0 -2.352713
# 412          2017-01-01       5.0        1.0        1.0 -2.352713
# 413          2017-01-01       5.0        1.0        1.0 -2.352713
# 414          2017-01-01       5.0        1.0        1.0 -2.352713
# 415          2017-01-01       5.0        1.0        1.0 -2.352713
# 416          2017-01-01       5.0        1.0        1.0 -2.352713
# 417          2017-01-01       5.0        1.0        1.0 -2.352713
# 418          2017-01-01       5.0        1.0        1.0 -2.352713
# 419          2017-01-01       5.0        1.0        1.0 -2.352713
# 420          2017-01-01       5.0        1.0        1.0 -2.352713
# 421          2017-01-01       5.0        1.0        1.0 -2.352713
# 422          2017-01-01       5.0        1.0        1.0 -2.352713
# 423          2017-01-01       5.0        1.0        1.0 -2.352713
# 424          2017-01-01       5.0        1.0        1.0 -2.352713
# 425          2017-01-01       5.0        1.0        1.0 -2.352713
# 426          2017-01-01       5.0        1.0        1.0 -2.352713
# 427          2017-01-01       5.0        1.0        1.0 -2.352713
# 428          2017-01-01       5.0        1.0        1.0 -2.352713
# 429          2017-01-01       5.0        1.0        1.0 -2.352713
#
#      month_diff1  outliers
# 400           13     False
# 401           13     False
# 402           14     False
# 403           13     False
# 404           13     False
# 405           13     False
# 406           13     False
# 407           13     False
# 408           13     False
# 409           13     False
# 410           13     False
# 411           13     False
# 412           13     False
# 413           13     False
# 414           13     False
# 415           13     False
# 416           14     False
# 417           13     False
# 418           13     False
# 419           13     False
# 420           14     False
# 421           14     False
# 422           14     False
# 423           14     False
# 424           14     False
# 425           13     False
# 426           13     False
# 427           14     False
# 428           13     False
# 429           13     False
#
# [30 rows x 21 columns]

# %%
df_merge_hist.category_3.value_counts(dropna=False)
# Out:
# A      9498070
# B      7116025
# C      1125938
# NaN     109871
# Name: category_3, dtype: int64

# %%
df_merge_hist.category_2.value_counts(dropna=False)
# Out:
#  1.0    9417553
#  3.0    2426416
#  5.0    2295169
# NaN     1637392
#  4.0    1617762
#  2.0     635717
# Name: category_2, dtype: int64

# %%
df_merge_hist.category_1.value_counts(dropna=False)
# Out:
# N    16741908
# Y     1288101
# Name: category_1, dtype: int64

# %%
df_merge_hist.installments.value_counts(dropna=False)
# Out:
#  0      9552206
#  1      7222525
#  2       413526
#  3       334193
#  4       110663
# -1       110513
#  6        82319
#  10       74064
#  5        72111
#  12       33980
#  8        12841
#  7         6884
#  9         3558
#  11         520
#  999        106
# Name: installments, dtype: int64

# %%
fig = plt.figure(figsize=(8,4))
ax = fig.add_axes((0,0,1,1))
sns.distplot(df_merge_hist['purchase_date'], bins =250,kde=False,color='green')

# %%
from scipy import stats

# %%
df_month_diff1 = df_merge_hist[['target','month_diff1','card_id','outliers']].groupby('card_id').agg({'outliers':'mean','month_diff1':(lambda x: stats.mode(x)[0][0]),'target':'mean'})

# %%
df_month_diff1.reset_index(inplace=True)

# %%
df_month_diff1.head()
# Out:
#            card_id  month_diff1  outliers    target
# 0  C_ID_00007093c1           11     False  0.134077
# 1  C_ID_0001506ef0           11     False  0.884295
# 2  C_ID_000183fdda           11     False -0.264433
# 3  C_ID_00027503e2           12     False  0.812872
# 4  C_ID_0002c7c2c1           12     False  1.288514

# %%
plt_data = df_month_diff1.groupby('month_diff1').target.mean()

# %%
plt_data = plt_data.reset_index()

# %%
plt_data
# Out:
#     month_diff1    target
# 0            11  0.049307
# 1            12 -0.093406
# 2            13 -0.149355
# 3            14 -0.537702
# 4            15 -0.488502
# 5            16 -0.026787
# 6            17 -0.070801
# 7            18 -0.317819
# 8            19 -0.341099
# 9            20 -0.234117
# 10           21 -0.229832
# 11           22 -0.258266
# 12           23 -0.185057
# 13           24  0.541005

# %%
##without outliers
plt.scatter(x=plt_data.month_diff1,y=plt_data.target)

# %%
##with outliers
plt.scatter(x=plt_data.month_diff1,y=plt_data.target)

# %%
df_merge_hist.state_id.value_counts(dropna=False)/df_merge_hist.shape[0]
# Out:
#  9     0.363845
# -1     0.090815
#  16    0.073869
#  15    0.071122
#  5     0.056440
#  19    0.041178
#  20    0.038277
#  22    0.032723
#  21    0.032580
#  4     0.029083
#  11    0.022104
#  13    0.021901
#  7     0.021797
#  3     0.018672
#  18    0.013527
#  12    0.013490
#  2     0.012893
#  1     0.008616
#  10    0.007420
#  24    0.007156
#  23    0.006920
#  14    0.006020
#  8     0.005339
#  17    0.003979
#  6     0.000236
# Name: state_id, dtype: float64

# %%
df_merge_hist.month_lag.value_counts(dropna=False)
# Out:
# -2     2389787
# -1     2248468
#  0     2151419
# -3     1920958
# -4     1635925
# -5     1466671
# -6     1271559
# -7     1098685
# -8      882416
# -9      761224
# -10     668862
# -11     620200
# -12     488207
# -13     425628
# Name: month_lag, dtype: int64

# %%
month_lag = df_merge_hist[['target','month_lag','card_id']].groupby('card_id').agg({'month_lag':(lambda x: stats.mode(x)[0][0]),'target':'mean'})

# %%
month_lag.reset_index(inplace=True)

# %%
month_lag.groupby('month_lag').target.mean()
# Out:
# month_lag
# -13    0.155046
# -12    0.091679
# -11    0.029857
# -10    0.039961
# -9     0.024476
# -8     0.055755
# -7     0.066167
# -6     0.047462
# -5    -0.007139
# -4     0.024361
# -3     0.001315
# -2    -0.028485
# -1    -0.093651
#  0    -0.210636
# Name: target, dtype: float64

# %%
month_lag.month_lag.value_counts(dropna=False)
# Out:
# -2     36619
# -1     29604
#  0     27679
# -3     21899
# -4     16126
# -5     14066
# -6     11842
# -7     10206
# -8      6790
# -9      5846
# -11     5605
# -10     5242
# -13     4281
# -12     3905
# Name: month_lag, dtype: int64

# %%
plt_data_2 = month_lag.groupby('month_lag').target.mean()
plt_data_2 = plt_data_2.reset_index()

# %%
plt.scatter(x=plt_data_2.month_lag,y=plt_data_2.target)

# %%
pd.read_csv('score_dict_80_top_feature.csv',header=None).sort_values\
(by = 1,ascending=False)
# Out:
#                                           0         1
# 31        authorized_purchase_month_nunique  3.658425
# 53                    new_purchase_date_ptp  3.655836
# 1                 authorized_category_1_sum  3.654392
# 11              authorized_installments_std  3.654199
# 34            authorized_weekofyear_nunique  3.654157
# 14           authorized_merchant_id_nunique  3.654110
# 33          authorized_subsector_id_nunique  3.654106
# 62           unauthorized_installments_mean  3.654093
# 73           unauthorized_purchase_date_ptp  3.654071
# 28             authorized_purchase_date_min  3.654048
# 45                      new_month_diff3_sum  3.653994
# 32            authorized_purchase_month_std  3.653987
# 57          unauthorized_category_2_1.0_sum  3.653981
# 71        unauthorized_purchase_amount_mean  3.653968
# 6               authorized_category_3_B_sum  3.653967
# 4             authorized_category_2_4.0_sum  3.653924
# 76          unauthorized_purchase_month_std  3.653923
# 5              authorized_category_3_B_mean  3.653813
# 38                       new_category_1_sum  3.653808
# 36                                    month  3.653781
# 51                    new_purchase_date_max  3.653777
# 68             unauthorized_month_diff2_sum  3.653771
# 79          unauthorized_weekofyear_nunique  3.653767
# 42                     new_month_diff1_mean  3.653761
# 74         unauthorized_purchase_month_mean  3.653758
# 47                  new_purchase_amount_max  3.653748
# 46                       new_month_lag_mean  3.653685
# 25           authorized_purchase_amount_std  3.653684
# 66            unauthorized_month_diff1_mean  3.653673
# 3            authorized_category_2_4.0_mean  3.653664
# ..                                      ...       ...
# 56              unauthorized_category_1_sum  3.653395
# 7              authorized_category_3_C_mean  3.653386
# 48                 new_purchase_amount_mean  3.653377
# 27             authorized_purchase_date_max  3.653368
# 12              authorized_installments_sum  3.653349
# 15              authorized_month_diff1_mean  3.653333
# 52                    new_purchase_date_min  3.653315
# 78                 unauthorized_weekend_sum  3.653309
# 50                  new_purchase_amount_std  3.653280
# 35                             elapsed_time  3.653269
# 30           authorized_purchase_month_mean  3.653267
# 63            unauthorized_installments_std  3.653247
# 67             unauthorized_month_diff1_sum  3.653243
# 17               authorized_month_diff2_max  3.653218
# 39                     new_category_3_A_sum  3.653182
# 8               authorized_category_3_C_sum  3.653169
# 22           authorized_purchase_amount_max  3.653166
# 18               authorized_month_diff2_sum  3.653165
# 54                   new_purchase_month_std  3.653139
# 9                authorized_city_id_nunique  3.653133
# 43                      new_month_diff1_sum  3.653109
# 41                    new_installments_mean  3.653106
# 23          authorized_purchase_amount_mean  3.653019
# 24           authorized_purchase_amount_min  3.652955
# 70               unauthorized_month_lag_sum  3.652947
# 13  authorized_merchant_category_id_nunique  3.652906
# 64            unauthorized_installments_sum  3.652835
# 37                      new_category_1_mean  3.652802
# 40                    new_category_3_B_mean  3.652765
# 26           authorized_purchase_amount_sum  3.652675
#
# [80 rows x 2 columns]
